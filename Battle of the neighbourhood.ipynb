# %% [markdown]
# ## Introduction
#
# #### Do you want some bubble tea?
#
# Kuala Lumpur, Malaysia has a bubble tea craze for the recent year. According to Bubble Tea Malaysia, there are more than 102 bubble tea brands in Malaysia currently.
#
# The bubble tea craze great a lot of business opportunity as well as competition. Small business owners (franchisee prospects) are spoilt with choice over the franchise they can choose from, but in the same time, the competition has never been fiercer. It is crucial for these small business owners to pick the best brand out of it.
#
# But how do we define the best brand? To put it simply, the best brand at those with equally high rating across different shop. Quality control is essential for a franchaisee.
#
# Besides, as more and more bubble tea shop mushrooming all over the country. Finding a good location with maximum prospect and opportunity is essential. The common practice of franchiser is to limit the amount of shop under the same brand at a certain area to solely 1, spotting good location is very important. Since the capital was already crowded with bubble tea shop, for the prospectus, we are going to shift the arena to Penang Island and Ipoh, the second and third largest cities after Kuala Lumpur (Klang Valley).
#
# To summarized, the problem statement are as listed below:
#
# By studying the performance of Bubble tea shop at Kuala Lumpur, find the best bubble tea brand. Rate the bubble tea base on:
# size (no of outlet)
# average rating
# The current bubble tea situation in Ipoh and Penang.
# Where is the best location if a franchisee plan to start up another bubble tea shop around Ipoh and Penang?
# The audiences of my report are the prospect bubble tea franchisees. The report was intended to provide them with valuable overview of the bubble tea industry as a whole while in the same time, provide some idea on the suitable location for their next venture.

# %% [markdown]
# ## Data
#
# The data that we needed for this analysis comes from Foursquare API.
#
# Some of the field neccessary for the search included name, location, categories, price, rating, beenHere and etc. Rating and Beenhere are used to explore the popularity and the quality of the brand. A brand is consider superior with high and consistent rating, as well as high Beenhere.
#
# According to Foursquare, the categories of venue included bubble tea shop, we are going to utilize it to get the location of all bubble tea shops around the specific location.
#
# The locations we are going to include in the study are Penang, Ipoh and Kuala Lumpur (or included Klang Valley) depend on the data.
#
# To study the suitable location for other bubble tea shop, we are going to utilized the categories of venue Café. Since in Malaysia context, the bubble tea shop function like a Café but selling other beverages, the hypothesis was that the absent of bubble tea shop in area with high density of cafe provides exhibit an apportunity that yet to explore for bubble tea shop.
#
# The list of data needed:
# 1. Bubble tea shop data
# 2. Cafe
#
# Location
# 1. Kuala Lumpur (Klang Valley)
# 2. Penang
# 3. Ipoh
#
# Features:
# 1. Name
# 2. Location (longitude, lattitude)
# 3. Categories
# 4. Price
# 5. Rating
# 6. BeenHere

# %% [markdown]
# ## Methodology / Analysis

# %% [markdown]
# We must first import the library need for the analysis.

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker

# %%
# !conda install -c conda-forge geocoder --yes
print("Installation Done!")
import geocoder # import geocoder
print("Geo Coder imported!")
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geocoder
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     geocoder-1.38.1            |             py_1          53 KB  conda-forge
#     ratelim-0.1.6              |             py_2           6 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.4 MB
#
# The following NEW packages will be INSTALLED:
#
#     geocoder:        1.38.1-py_1       conda-forge
#     ratelim:         0.1.6-py_2        conda-forge
#
# ...

# %%
# !pip install folium
import folium
# Out:
# ...
#      |████████████████████████████████| 92kB 15.3MB/s eta 0:00:01
# ...

# %%
import requests

# %%
CLIENT_ID = 'JHGHB3FKGLWICVH2VJVWJ0AGNXVCCLNDMC41Q2YLZJMPNCZX' # your Foursquare ID
CLIENT_SECRET = 'NTRNCIX050S1YHMFA3YGPDYHGCWEPZOVJ0XAZFTMVED5XA32' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: JHGHB3FKGLWICVH2VJVWJ0AGNXVCCLNDMC41Q2YLZJMPNCZX
# CLIENT_SECRET:NTRNCIX050S1YHMFA3YGPDYHGCWEPZOVJ0XAZFTMVED5XA32

# %%
import random
from IPython.display import Image 
from IPython.core.display import HTML 
from pandas.io.json import json_normalize
from geopy.geocoders import Nominatim

# %%
address = 'kuala lumpur'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 3.1516636 101.6943028

# %%
radius = '10000'
categoryID = '52e81612bcbc57f1066b7a0c'
search_query = 'bubble tea'

url = 'https://api.foursquare.com/v2/venues/search?query={}&client_id={}&client_secret={}&v={}&ll={},{}&radius={}'.format(search_query,CLIENT_ID,CLIENT_SECRET,VERSION,latitude,longitude,radius)

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e042e31216785001bf85e09'},
#  'response': {'venues': [{'id': '500cf937e4b0a62ff5624470',
#     'name': 'Froggy Bubble Tea Cafe 青蛙王子 热狗奶茶专买店',
#     'location': {'address': 'No.1 Jalan Balai Polis Jalan Bandar',
#      'lat': 3.141371751929503,
#      'lng': 101.69765520394226,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.141371751929503,
#        'lng': 101.69765520394226}],
#      'distance': 1204,
#      'postalCode': '50000',
#      'cc': 'MY',
#      'city': 'Kuala Lumpur',
#      'state': 'Kuala Lumpur',
#      'country': 'Malaysia',
#      'formattedAddress': ['No.1 Jalan Balai Polis Jalan Bandar',
#       '50000 Kuala Lumpur, Kuala Lumpur',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
# ...

# %% [markdown]
# Get relevant part of JSON and transform it into pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...    False
# 2  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...    False
# 4  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
#
#                          id                     location.address location.cc  \
# 0  500cf937e4b0a62ff5624470  No.1 Jalan Balai Polis Jalan Bandar          MY
# 1  4db8fe7e93a0f369e865fdf2                     Jalan Hang Lekiu          MY
# 2  50498803e4b0982c451fc2a6                             Dayabumi          MY
# 3  50bf0a92e4b007de9b95ff94                          Busana Mara          MY
# 4  57525191498e1f2ce7090a71                                  NaN          MY
#
#   location.city location.country location.crossStreet  location.distance  \
# ...

# %%
dataframe.shape
# Out:
# (30, 18)

# %% [markdown]
# With only 30 locations, foursquare might not work well for Malaysia. Indeed, foursquare is not a popular platform in Malaysia for location data. To work around, let's try with Google API.

# %%
Gurl = 'https://maps.googleapis.com/maps/api/place/textsearch/json?input=bubble+tea&location=3.13871,101.6943028&radius=1&key=AIzaSyCkfYBekqjopMkRXO964Z54a5OXbG1ahE8'

# %%
results = requests.get(Gurl).json()
results
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCIwEAAGMP87oEtT2Haug2tScTHzlZFDYpDCiffg3sJ5jP79kc9vnjg7CNPkcm_48eXR8NgE0jyYoGR_RcYQAve9qp9mxosi1SMHVCZhDzCqnTDgA1GgiRUqJKllYNmlmTSFVhHtSXO678WUnYGEVNZFxEAq6nFx00s2bZJm0SxKC0LgqarlMMIBZrYt13ENmeyd2hlULJlfHHp0bFCWQRNpp0z5VizL17CLna1hGPUUp-s7Dt_cRKDSw1w1PBpp8BxSVVUtVugMMy_P7kdFCjnJV79l9prSQ2VPl3Ke7laQzMQzvF3znQVG5Yy_8RhKwXehTMkZ2EmtYsjzxQSfzYnQm_ZNlh89h5DW2P7vWu5n6fg1LaD2IDvjZtCHEd6viyW0suzb9b5qcysordr8PY0PLRipASEMz-Ab_uc8SM6sN6TqXflU8aFPimTD1xE2HU--I5VKkiEGznNkEO',
#  'results': [{'formatted_address': 'Concourse Area K, 4, Jalan Sultan Mohamed, Stesen LRT Pasar Seni, 50050 Kuala Lumpur, Federal Territory of Kuala Lumpur, Malaysia',
#    'geometry': {'location': {'lat': 3.142501, 'lng': 101.6953285},
#     'viewport': {'northeast': {'lat': 3.143846829892722,
#       'lng': 101.6967503798927},
#      'southwest': {'lat': 3.141147170107277, 'lng': 101.6940507201073}}},
# ...

# %%
dt=results['results']

# %%
# assign relevant part of JSON to venues
#venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(dt)
dataframe.head()
# Out:
#                                    formatted_address  geometry.location.lat  \
# 0  Concourse Area K, 4, Jalan Sultan Mohamed, Ste...               3.142501
# 1  29a, Jalan Tun Tan Cheng Lock, City Centre, 50...               3.145291
# 2  Lot 2-35 Lingkaran SV Sunway Velocity Mall, 55...               3.126457
# 3  L5.07 , Level 5th Floor, Nu sentral Shopping C...               3.133071
# 4  7, Bukit Bintang Street, Bukit Bintang, 55100 ...               3.144145
#
#    geometry.location.lng  geometry.viewport.northeast.lat  \
# 0             101.695329                         3.143847
# 1             101.698446                         3.146687
# 2             101.725219                         3.127822
# 3             101.687035                         3.134221
# 4             101.710130                         3.145644
#
#    geometry.viewport.northeast.lng  geometry.viewport.southwest.lat  \
# 0                       101.696750                         3.141147
# ...

# %%
dataframe.shape
# Out:
# (20, 20)

# %% [markdown]
# While Google API did provide the data needed, however, there's still a problem where google only limit to 20 result for location. However, since the result of KL bubbles tea was only used for study purposes, i'll just sampling the same bubble tea at other location around kuala lumpur to get more result for analysis.

# %%
KL_bubble_tea = dataframe

# %%
Gurl2 = 'https://maps.googleapis.com/maps/api/place/textsearch/json?input=bubble+tea+kepong&key=AIzaSyCkfYBekqjopMkRXO964Z54a5OXbG1ahE8'

results2 = requests.get(Gurl2).json()
results2
# Out:
# {'html_attributions': [],
#  'results': [{'formatted_address': '47, Jalan Rimbunan Raya 1, Laman Rimbunan, 52100 Kuala Lumpur, Wilayah Persekutuan Kuala Lumpur, Malaysia',
#    'geometry': {'location': {'lat': 3.2108036, 'lng': 101.6504045},
#     'viewport': {'northeast': {'lat': 3.212104229892722,
#       'lng': 101.6517260298927},
#      'southwest': {'lat': 3.209404570107278, 'lng': 101.6490263701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '7ae3e49d5c87fc3bbfea0b30c0b359978fce9a22',
#    'name': 'The Alley @Kepong',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100513330302437923447">Nicholas Lim</a>'],
#      'photo_reference': 'CmRaAAAAgfTA09RXfvm-Jb8g5Sx7c4CdOOfK3roe7t4eDcCiSXwD0y2-d0KRl3W7giftMeiecdzqfsp9nRzWQy1eyIMKxEZPo0-fhbPV2nkOovmn-lPToo6T363p-bUp02NgsqgBEhCYhrC4xUkK1eXCn7QMxL3jGhRQy5buhqym5FoGUFg-k7KBA3_xBQ',
# ...

# %%
Gurl3 = 'https://maps.googleapis.com/maps/api/place/textsearch/json?input=bubble+tea+wangsa+maju&key=AIzaSyCkfYBekqjopMkRXO964Z54a5OXbG1ahE8'

results3 = requests.get(Gurl3).json()
results3
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CpQCBQEAAJeXF8Ot26-kac3_nY-k1gOfmZb8EdJJ45L6yWh9EjLCv0KyDsseepW52tl4rX0hJXmeXr02NPkq9wcciiGD43jnmf6ZH4SQfaV_i2ek49_Sl2nw9Se0c5Fv7JmSjYORyz-w2u81dOUg4u7TgaHUefnPG9TsI_LsznbLO_qCw_O13QGV_yzODUJizjjc7TbRuqIGbxUCAy7vGbYTWPBsf_hpVzp6qv7Dvp9M-tQKkOKUIntwsB3myC4RMyEnIsPkqNb9FnN1CKiryKRQTjKmyiVN3_12nt4pLnF3GgFtQCuJcHFp8ZQALfrlnYCRiwdDJttYUvnZtMrRfNlkgjCJoSvx9o6FXUaA7NUA0WEPGywyEhBaGhS7PB_WgTuULwN8WWhUGhTae-AHNh29CBG7-4ArkHS6q6t97g',
#  'results': [{'formatted_address': 'Lot SK-02, Wangsa Avenue, No. 9, Jalan Wangsa Perdana 1, Wangsa Maju, Kuala Lumpur, Federal Territory of Kuala Lumpur, Malaysia',
#    'geometry': {'location': {'lat': 3.1982579, 'lng': 101.742199},
#     'viewport': {'northeast': {'lat': 3.199461079892722,
#       'lng': 101.7436608798927},
#      'southwest': {'lat': 3.196761420107278, 'lng': 101.7409612201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
# ...

# %%
Gurl4 = 'https://maps.googleapis.com/maps/api/place/textsearch/json?input=bubble+tea+sri+petaling&key=AIzaSyCkfYBekqjopMkRXO964Z54a5OXbG1ahE8'

results4 = requests.get(Gurl4).json()
results4
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CpQCBgEAAI3qNVSzi2U2xvEsT4OfQtPmje6JkIFonBGrcEDxsmSbwAVdVyC9lyo3VBPfolPfo6B7K4-pkxDqgWsVaG9tYyD0qfvqenSS57GUHNZgYQo6t_TN8lB-ZZXXIEOT6ve_CkaFUQXJbU9DkaBhlV3J6nfqasmpsxODC1CklpL6eW2TQqPeut8R8oTKizCJCDYzW28NHMJW3TKyi2aepGJBtN3y_tgg_y7WmmZUVs-x44-6FBS35V6nCEsunopl9dXaJOBts50ddVPmPiSs_D_Qw_oxpUxNHmVyAnhOrrS-CY4x2PqUfC5S7hDKzYPBtf48UQ_M6LY51P_kv56WRGUHWY7hFWSVVs7J5AulU9s04ay2EhAEfZFG7bFTRd1pN7XNApUBGhQ4Dc3Ozse1dnxe9E6AzHUy-WzRDQ',
#  'results': [{'formatted_address': '10, Jln Radin Bagus 7, Sri Petaling, 57000 Kuala Lumpur, Wilayah Persekutuan Kuala Lumpur, Malaysia',
#    'geometry': {'location': {'lat': 3.0706586, 'lng': 101.692361},
#     'viewport': {'northeast': {'lat': 3.072008629892722,
#       'lng': 101.6937061798927},
#      'southwest': {'lat': 3.069308970107278, 'lng': 101.6910065201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '2128e96236406caebd33e0edea54e6e5ba2b9135',
# ...

# %%
Gurl5 = 'https://maps.googleapis.com/maps/api/place/textsearch/json?input=bubble+tea+bangsar&key=AIzaSyCkfYBekqjopMkRXO964Z54a5OXbG1ahE8'

results5 = requests.get(Gurl5).json()
results5
# Out:
# {'html_attributions': [],
#  'results': [{'formatted_address': '2, Jalan Telawi 1, Bangsar Baru, 59100 Kuala Lumpur, Wilayah Persekutuan Kuala Lumpur, Malaysia',
#    'geometry': {'location': {'lat': 3.1294873, 'lng': 101.670624},
#     'viewport': {'northeast': {'lat': 3.130642829892722,
#       'lng': 101.6719806798927},
#      'southwest': {'lat': 3.127943170107278, 'lng': 101.6692810201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '33eca418f8c617b907c3b7e797e280a6bdb80529',
#    'name': 'Tealive',
#    'place_id': 'ChIJAR-NsplJzDERb5ZR9dObkTU',
#    'plus_code': {'compound_code': '4MHC+Q6 Kuala Lumpur, Federal Territory of Kuala Lumpur, Malaysia',
#     'global_code': '6PM34MHC+Q6'},
#    'rating': 1,
#    'reference': 'ChIJAR-NsplJzDERb5ZR9dObkTU',
#    'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1},
# ...

# %%
dt2=results2['results']

dataframe2 = json_normalize(dt2)
dataframe2.head()
# Out:
#                                    formatted_address  geometry.location.lat  \
# 0  47, Jalan Rimbunan Raya 1, Laman Rimbunan, 521...               3.210804
# 1  41, Jalan Metro Perdana Barat 1, Taman Usahawa...               3.214793
# 2  129, Jalan Rimbunan Raya 1 KEPONG, Laman Rimbu...               3.212175
# 3  Metro Prima, 52100 Kuala Lumpur, Federal Terri...               3.213212
# 4  2, Ground Floor, Fortune Avenue, A-G, Jalan Me...               3.217117
#
#    geometry.location.lng  geometry.viewport.northeast.lat  \
# 0             101.650404                         3.212104
# 1             101.640291                         3.216099
# 2             101.648080                         3.213537
# 3             101.634963                         3.214565
# 4             101.644623                         3.218233
#
#    geometry.viewport.northeast.lng  geometry.viewport.southwest.lat  \
# 0                       101.651726                         3.209405
# ...

# %%
KL_bubble_tea2=KL_bubble_tea.append(dataframe2)

# %%
KL_bubble_tea2.shape
# Out:
# (38, 20)

# %% [markdown]
# Well my clumsy coding seems like working, now lets unpack all and append it into the pandas dataframe.

# %%
dt3=results3['results']

dataframe3 = json_normalize(dt3)

KL_bubble_tea3=KL_bubble_tea2.append(dataframe3)
KL_bubble_tea3.shape
# Out:
# (58, 20)

# %%
dt4=results4['results']

dataframe4 = json_normalize(dt4)

KL_bubble_tea4=KL_bubble_tea3.append(dataframe4)
KL_bubble_tea4.shape
# Out:
# (78, 20)

# %%
dt5=results5['results']

dataframe5 = json_normalize(dt5)

KL_bubble_tea5=KL_bubble_tea4.append(dataframe5)
KL_bubble_tea5.shape
# Out:
# (92, 20)

# %%
KLBT = KL_bubble_tea5

KLBT.head()
# Out:
#                                    formatted_address  geometry.location.lat  \
# 0  Concourse Area K, 4, Jalan Sultan Mohamed, Ste...               3.142501
# 1  29a, Jalan Tun Tan Cheng Lock, City Centre, 50...               3.145291
# 2  Lot 2-35 Lingkaran SV Sunway Velocity Mall, 55...               3.126457
# 3  L5.07 , Level 5th Floor, Nu sentral Shopping C...               3.133071
# 4  7, Bukit Bintang Street, Bukit Bintang, 55100 ...               3.144145
#
#    geometry.location.lng  geometry.viewport.northeast.lat  \
# 0             101.695329                         3.143847
# 1             101.698446                         3.146687
# 2             101.725219                         3.127822
# 3             101.687035                         3.134221
# 4             101.710130                         3.145644
#
#    geometry.viewport.northeast.lng  geometry.viewport.southwest.lat  \
# 0                       101.696750                         3.141147
# ...

# %% [markdown]
# Now finally we got a list of sampling of buuble tea shop around KL, since the place was query by numerous attempt, lets clean the dataframe.

# %%
KLBT.describe()
# Out:
#        geometry.location.lat  geometry.location.lng  \
# count              92.000000              92.000000
# mean                3.148077             101.692479
# std                 0.052954               0.032749
# min                 3.035692             101.627908
# 25%                 3.117869             101.671076
# 50%                 3.145559             101.694214
# 75%                 3.199142             101.713461
# max                 3.217338             101.764838
#
#        geometry.viewport.northeast.lat  geometry.viewport.northeast.lng  \
# count                        92.000000                        92.000000
# mean                          3.149422                       101.693827
# std                           0.052948                         0.032746
# min                           3.037018                       101.629237
# 25%                           3.119211                       101.672370
# ...

# %%
KLBT2=KLBT.drop(['geometry.viewport.northeast.lat','geometry.viewport.northeast.lng','geometry.viewport.southwest.lat','geometry.viewport.southwest.lng','icon','id'],axis = 1)
KLBT2.head()
# Out:
#                                    formatted_address  geometry.location.lat  \
# 0  Concourse Area K, 4, Jalan Sultan Mohamed, Ste...               3.142501
# 1  29a, Jalan Tun Tan Cheng Lock, City Centre, 50...               3.145291
# 2  Lot 2-35 Lingkaran SV Sunway Velocity Mall, 55...               3.126457
# 3  L5.07 , Level 5th Floor, Nu sentral Shopping C...               3.133071
# 4  7, Bukit Bintang Street, Bukit Bintang, 55100 ...               3.144145
#
#    geometry.location.lng                                   name  \
# 0             101.695329                                Tealive
# 1             101.698446  TAIONE Tea @ Jalan Tun Tan Cheng Lock
# 2             101.725219       Tiger Sugar Sunway Velocity Mall
# 3             101.687035                      Chatto NU Sentral
# 4             101.710130               Gong Cha (Plaza Low Yat)
#
#   opening_hours.open_now                                             photos  \
# ...

# %%
KLBT3=KLBT2.drop(['opening_hours.open_now','photos','place_id','plus_code.compound_code','plus_code.global_code','reference','types'],axis=1)
KLBT3.head()
# Out:
#                                    formatted_address  geometry.location.lat  \
# 0  Concourse Area K, 4, Jalan Sultan Mohamed, Ste...               3.142501
# 1  29a, Jalan Tun Tan Cheng Lock, City Centre, 50...               3.145291
# 2  Lot 2-35 Lingkaran SV Sunway Velocity Mall, 55...               3.126457
# 3  L5.07 , Level 5th Floor, Nu sentral Shopping C...               3.133071
# 4  7, Bukit Bintang Street, Bukit Bintang, 55100 ...               3.144145
#
#    geometry.location.lng                                   name  price_level  \
# 0             101.695329                                Tealive          2.0
# 1             101.698446  TAIONE Tea @ Jalan Tun Tan Cheng Lock          NaN
# 2             101.725219       Tiger Sugar Sunway Velocity Mall          NaN
# 3             101.687035                      Chatto NU Sentral          NaN
# 4             101.710130               Gong Cha (Plaza Low Yat)          NaN
#
#    rating  user_ratings_total
# ...

# %% [markdown]
# now we got a clean list, lets plot it into a maps.

# %%
KLBT3.rename(columns={'geometry.location.lat':'latitude',
                          'geometry.location.lng':'longitude',
                          'formatted_address':'address'}, 
                 inplace=True)

# %%
KLBT3.head()
# Out:
#                                              address  lattitude   longitude  \
# 0  Concourse Area K, 4, Jalan Sultan Mohamed, Ste...   3.142501  101.695329
# 1  29a, Jalan Tun Tan Cheng Lock, City Centre, 50...   3.145291  101.698446
# 2  Lot 2-35 Lingkaran SV Sunway Velocity Mall, 55...   3.126457  101.725219
# 3  L5.07 , Level 5th Floor, Nu sentral Shopping C...   3.133071  101.687035
# 4  7, Bukit Bintang Street, Bukit Bintang, 55100 ...   3.144145  101.710130
#
#                                     name  price_level  rating  \
# 0                                Tealive          2.0     4.1
# 1  TAIONE Tea @ Jalan Tun Tan Cheng Lock          NaN     5.0
# 2       Tiger Sugar Sunway Velocity Mall          NaN     4.3
# 3                      Chatto NU Sentral          NaN     5.0
# 4               Gong Cha (Plaza Low Yat)          NaN     4.2
#
#    user_ratings_total
# 0                  45
# 1                   2
# 2                  37
# 3                   5
# ...

# %% [markdown]
# And we have to drop the duplicates first, since the result was query base of few query.

# %%
KLBT3.drop_duplicates(inplace=True)
KLBT3.shape
# Out:
# (89, 7)

# %%
map_KLBT = folium.Map(location=[3.1390,101.6869], zoom_start=11)

# add markers to map
for lat, lng, label in zip(KLBT3['lattitude'], KLBT3['longitude'], KLBT3['name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_KLBT)  
    
map_KLBT
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Yes, the maps shows the location of all the location we got. Now to find the best, let's see the descriptive statistics of the data.

# %%
KLBT3.describe()
# Out:
#        lattitude   longitude  price_level     rating  user_ratings_total
# count  89.000000   89.000000         24.0  89.000000           89.000000
# mean    3.148318  101.692302          2.0   3.733708          103.505618
# std     0.053825    0.033230          0.0   1.147818          352.774816
# min     3.035692  101.627908          2.0   0.000000            0.000000
# 25%     3.117592  101.670624          2.0   3.600000            3.000000
# 50%     3.145827  101.694195          2.0   4.000000           12.000000
# 75%     3.199957  101.715409          2.0   4.300000           62.000000
# max     3.217338  101.764838          2.0   5.000000         2415.000000

# %% [markdown]
# As we can see, the top 25% of the bubble tea shop received at least 4.3 rating. Thus, we have to filter out the company with 4.3 rating.

# %%
KLBT3.dtypes
# Out:
# address                object
# lattitude             float64
# longitude             float64
# name                   object
# price_level           float64
# rating                float64
# user_ratings_total      int64
# dtype: object

# %%
KLBT3[KLBT3['rating'] > 4.3]
# Out:
#                                               address  lattitude   longitude  \
# 1   29a, Jalan Tun Tan Cheng Lock, City Centre, 50...   3.145291  101.698446
# 3   L5.07 , Level 5th Floor, Nu sentral Shopping C...   3.133071  101.687035
# 19  46, Jalan Sultan Ismail, Bukit Bintang, 50250 ...   3.147342  101.711305
# 0   47, Jalan Rimbunan Raya 1, Laman Rimbunan, 521...   3.210804  101.650404
# 3   Metro Prima, 52100 Kuala Lumpur, Federal Terri...   3.213212  101.634963
# 5   No. 37, Jalan 3/62a, Bandar Menjalara, 52200 K...   3.195051  101.629866
# 9   68, Jalan Metro Perdana Barat 2, Taman Usahawa...   3.215159  101.639316
# 12  Jalan Metro Perdana 2, Taman Usahawan, 52100 K...   3.216780  101.644149
# 15  26, Jalan 8/38a, Taman Sri Sinar, 51200 Kuala ...   3.186577  101.650992
# 8   Kuala Lumpur MY, Jalan Maju Ria 1, Wangsa Maju...   3.191822  101.734983
# 11  No. 126-G-3A, 126 Metro Genting Kelang, Jalan ...   3.198668  101.715409
# ...

# %% [markdown]
# While we see tealive and the alley is a more common name that received high rating. let's see is that a conclusive answer by looking at other rating of tealive and the alley.

# %%
KLBT3[KLBT3['name'].str.contains("Alley")]
# Out:
#                                               address  lattitude   longitude  \
# 19  46, Jalan Sultan Ismail, Bukit Bintang, 50250 ...   3.147342  101.711305
# 0   47, Jalan Rimbunan Raya 1, Laman Rimbunan, 521...   3.210804  101.650404
# 11  No. 126-G-3A, 126 Metro Genting Kelang, Jalan ...   3.198668  101.715409
# 17  No. 8-G, Jln Radin Bagus 8, Sri Petaling, 5700...   3.070428  101.691718
#
#                       name  price_level  rating  user_ratings_total
# 19               The Alley          NaN     4.7                   3
# 0        The Alley @Kepong          2.0     4.4                 557
# 11       The Alley Setapak          2.0     4.8                2415
# 17  The Alley Sri Petaling          NaN     4.7                2239

# %%
KLBT3[KLBT3['name'].str.contains("live")]
# Out:
#                                               address  lattitude   longitude  \
# 0   Concourse Area K, 4, Jalan Sultan Mohamed, Ste...   3.142501  101.695329
# 6   Berjaya Times Square, LG-18D-1, Lower Ground F...   3.142300  101.709971
# 8   L5.08-NU-SENTRAL, KUALA LUMPUR-SENTRAL, 201, J...   3.134442  101.686155
# 9   45, 6, Jalan Tun Perak, Kuala Lumpur City Cent...   3.148388  101.697175
# 11  Shopping Centre, LTC/T4, Lot 10, Bintang Terra...   3.145827  101.711776
# 18  Pavilion, 1.110.00 Level 1, Elite, 168, Bukit ...   3.149050  101.712472
# 2   129, Jalan Rimbunan Raya 1 KEPONG, Laman Rimbu...   3.212175  101.648080
# 3   Metro Prima, 52100 Kuala Lumpur, Federal Terri...   3.213212  101.634963
# 8   Kepong The Waterfront @ Parkcity, 5, Persiaran...   3.186622  101.627908
# 9   68, Jalan Metro Perdana Barat 2, Taman Usahawa...   3.215159  101.639316
# 10  Lot KG2, Ground Floor, Jalan Metro Prima, Tama...   3.213215  101.639066
# ...

# %% [markdown]
# From the observation above, all The Alley receive rating that more than 4.3, while the performance of Tealive is vary from one to another, rating range from 1.0 to 5.0.

# %%
GurlPen = 'https://maps.googleapis.com/maps/api/place/textsearch/json?input=bubble+tea+georgetown+Penang&key=AIzaSyCkfYBekqjopMkRXO964Z54a5OXbG1ahE8'

resultsPen = requests.get(GurlPen).json()
resultsPen
# Out:
# {'html_attributions': [],
#  'next_page_token': '-ifmfiTiUYWCIFJ-27yian-OhbGFfs3kF0_kaU7GOtSs1CHvREuu5zyfroLbOS9syzXmltKVDOmWHdoW2cXmyfH1aADMwQzQjaObwP6m5ZrBl-kEhBzFpXs_mEFCrqALeUjpV3UGhQHKaGROddnv8S87y4-UaBqzEPO4g',
#  'results': [{'formatted_address': 'Plaza Gurney, 170-G-45A, Persiaran Gurney, 10250 George Town, Pulau Pinang, Malaysia',
#    'geometry': {'location': {'lat': 5.437505700000001, 'lng': 100.3098033},
#     'viewport': {'northeast': {'lat': 5.439090629892721,
#       'lng': 100.3108387298927},
#      'southwest': {'lat': 5.436390970107277, 'lng': 100.3081390701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '85c2530e6a1ae1b27aee3c10bd30dd64346b6aa4',
# ...

# %%
dtPen=resultsPen['results']

dfPen = json_normalize(dtPen)
dfPen.head()
# Out:
#                                    formatted_address  geometry.location.lat  \
# 0  Plaza Gurney, 170-G-45A, Persiaran Gurney, 102...               5.437506
# 1  Jalan Nagor, 10450 George Town, Pulau Pinang, ...               5.420904
# 2  170-B1-K23/25/26, B1, Plaza Gurney, Persiaran ...               5.438264
# 3  Lower Ground, Gurney Paragon Mall, Lot No. LG ...               5.435853
# 4  6H-1-20, Kios D All Season Place, Thean Teik H...               5.396298
#
#    geometry.location.lng  geometry.viewport.northeast.lat  \
# 0             100.309803                         5.439091
# 1             100.325771                         5.422227
# 2             100.309893                         5.439706
# 3             100.310837                         5.437264
# 4             100.290503                         5.397752
#
#    geometry.viewport.northeast.lng  geometry.viewport.southwest.lat  \
# 0                       100.310839                         5.436391
# ...

# %%
dfPen.shape
# Out:
# (20, 20)

# %%
dfPen2=dfPen.drop(['geometry.viewport.northeast.lat','geometry.viewport.northeast.lng','geometry.viewport.southwest.lat','geometry.viewport.southwest.lng','icon','id','opening_hours.open_now','photos','place_id','plus_code.compound_code','plus_code.global_code','reference','types'],axis = 1)


dfPen2.rename(columns={'geometry.location.lat':'latitude',
                          'geometry.location.lng':'longitude',
                          'formatted_address':'address'}, 
                 inplace=True)

dfPen2.head()
# Out:
#                                              address  latitude   longitude  \
# 0  Plaza Gurney, 170-G-45A, Persiaran Gurney, 102...  5.437506  100.309803
# 1  Jalan Nagor, 10450 George Town, Pulau Pinang, ...  5.420904  100.325771
# 2  170-B1-K23/25/26, B1, Plaza Gurney, Persiaran ...  5.438264  100.309893
# 3  Lower Ground, Gurney Paragon Mall, Lot No. LG ...  5.435853  100.310837
# 4  6H-1-20, Kios D All Season Place, Thean Teik H...  5.396298  100.290503
#
#                          name  price_level  rating  user_ratings_total
# 0  MEME XPRESS - Gurney Plaza          NaN     2.8                  13
# 1        The Alley Penang 鹿角巷          2.0     4.3                 190
# 2     Gong Cha (Gurney Plaza)          NaN     3.7                  39
# 3      Tealive Gurvey Paragon          NaN     3.5                  13
# 4                     Tealive          2.0     4.0                 119

# %%
dfPen2[dfPen2['name'].str.contains("Alley")]
# Out:
#                                              address  latitude   longitude  \
# 1  Jalan Nagor, 10450 George Town, Pulau Pinang, ...  5.420904  100.325771
# 6  48, Jalan Nagor, 10050 George Town, Pulau Pina...  5.420661  100.325629
#
#                    name  price_level  rating  user_ratings_total
# 1  The Alley Penang 鹿角巷          2.0     4.3                 190
# 6      The Alley Nagore          NaN     4.5                 734

# %%
map_Pen = folium.Map(location=[5.4356, 100.3091], zoom_start=12)

for lat, lng, label in zip(dfPen2['latitude'], dfPen2['longitude'], dfPen2['name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        popup=label,
        color='black',
        fill=True,
        fill_color='black',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Pen)  
    
map_Pen
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dfPen2.describe()
# Out:
#         latitude   longitude  price_level     rating  user_ratings_total
# count  20.000000   20.000000          6.0  20.000000           20.000000
# mean    5.428618  100.314884          2.0   3.735000           87.600000
# std     0.016157    0.011563          0.0   1.394831          190.391121
# min     5.396298  100.290503          2.0   0.000000            0.000000
# 25%     5.419939  100.308406          2.0   3.650000            3.000000
# 50%     5.432882  100.310965          2.0   4.100000           13.000000
# 75%     5.437915  100.325665          2.0   4.425000           40.500000
# max     5.450055  100.334918          2.0   5.000000          734.000000

# %%
dfPen2[dfPen2['rating'] > 4.425]
# Out:
#                                               address  latitude   longitude  \
# 6   48, Jalan Nagor, 10050 George Town, Pulau Pina...  5.420661  100.325629
# 7   163D-LG-P3b, Gurney Paragon Mall, Gurney Dr, 1...  5.435878  100.311092
# 8   g33, Jalan Dr Lim Chwee Leong, 10100 George To...  5.414683  100.331112
# 12     Gurney Dr, 10250 George Town, Penang, Malaysia  5.437383  100.309699
# 16  38 & 39, Jalan Pintal Tali, George Town, 10100...  5.417771  100.334918
#
#                       name  price_level  rating  user_ratings_total
# 6         The Alley Nagore          NaN     4.5                 734
# 7   TeaDaYe Gurney Paragon          NaN     5.0                   3
# 8                Cool Blog          2.0     4.6                   5
# 12             Tiger Sugar          NaN     5.0                   1
# 16      Leilomei by Manchu          NaN     5.0                   3

# %%
GurlIpoh = 'https://maps.googleapis.com/maps/api/place/textsearch/json?input=bubble+tea+ipoh&key=AIzaSyCkfYBekqjopMkRXO964Z54a5OXbG1ahE8'

resultsIpoh = requests.get(GurlIpoh).json()
resultsIpoh
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CoQC_gAAAM-qvjYSKwU2cft_9Xesao75cqLajuu47ZECA3xCIMR8TpIUOQPmwfoJx3lDcD1qNZvo1T7xuVOZJkZMzMYZISQIIMrylDVekdhPTCjHoJwzIVJOrolEVx2UdN3UdDA82ZObRFr2LYg6-mVd2hs0ozCtvEADNNra_m5Rkeax_WsgZigmhF_F8rTgL9eMQfFkzRv8K3UNj7KiJ5pi_gFL8q-aAfAB6E1pzBVcCABVvjgCKI4MkXMlk1YqKwyl0Py1bvfr8pQBrhdN_bKmMm8RuT-TLeCXIpXxjP_amJ9-lgo7a4hXc80HsF0azNIlPEdgjWQFKmgmZ19SulVWjO_mumgSEFplaywRaiFnnY8sldcwzRUaFMIT-YGNoQvyFwGYkm6uk_q0Iq0N',
#  'results': [{'formatted_address': '1, Jalan Langsat, Taman Teh Teng Seng, 31400 Ipoh, Negeri Perak, Malaysia',
#    'geometry': {'location': {'lat': 4.6150216, 'lng': 101.1174725},
#     'viewport': {'northeast': {'lat': 4.616423879892722,
#       'lng': 101.1188614298927},
#      'southwest': {'lat': 4.613724220107279, 'lng': 101.1161617701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '586cfe5c7a3eb188615a93ba0e25a1fc89a6e955',
#    'name': 'INSTEA Ipoh',
# ...

# %%
dtIpoh=resultsIpoh['results']

dfIpoh = json_normalize(dtIpoh)
dfIpoh.head()
# Out:
#                                    formatted_address  geometry.location.lat  \
# 0  1, Jalan Langsat, Taman Teh Teng Seng, 31400 I...               4.615022
# 1  Block D, G-3, Ipoh Soho, 2, Jalan Sultan Idris...               4.592451
# 2  BLOCK C, G2 (GROUND FLOOR) SOHO IPOH, Jalan Su...               4.593039
# 3         Taman Jubilee, 30300 Ipoh, Perak, Malaysia               4.591432
# 4  3rd floor, Ipoh Parade, 105, Jalan Sultan Abdu...               4.595913
#
#    geometry.location.lng  geometry.viewport.northeast.lat  \
# 0             101.117473                         4.616424
# 1             101.089959                         4.593796
# 2             101.089174                         4.594344
# 3             101.084509                         4.592728
# 4             101.090094                         4.597241
#
#    geometry.viewport.northeast.lng  geometry.viewport.southwest.lat  \
# 0                       101.118861                         4.613724
# ...

# %%
dfIpoh.shape
# Out:
# (20, 20)

# %%
dfIpoh2=dfIpoh.drop(['geometry.viewport.northeast.lat','geometry.viewport.northeast.lng','geometry.viewport.southwest.lat','geometry.viewport.southwest.lng','icon','id','opening_hours.open_now','photos','place_id','plus_code.compound_code','plus_code.global_code','reference','types'],axis = 1)


dfIpoh2.rename(columns={'geometry.location.lat':'latitude',
                          'geometry.location.lng':'longitude',
                          'formatted_address':'address'}, 
                 inplace=True)

dfIpoh2.head()
# Out:
#                                              address  latitude   longitude  \
# 0  1, Jalan Langsat, Taman Teh Teng Seng, 31400 I...  4.615022  101.117473
# 1  Block D, G-3, Ipoh Soho, 2, Jalan Sultan Idris...  4.592451  101.089959
# 2  BLOCK C, G2 (GROUND FLOOR) SOHO IPOH, Jalan Su...  4.593039  101.089174
# 3         Taman Jubilee, 30300 Ipoh, Perak, Malaysia  4.591432  101.084509
# 4  3rd floor, Ipoh Parade, 105, Jalan Sultan Abdu...  4.595913  101.090094
#
#                        name  price_level  rating  user_ratings_total
# 0               INSTEA Ipoh          NaN     3.9                 322
# 1       茶丸家 Tea Bubble Ipoh          2.0     4.0                 183
# 2  御黑堂 The Yunique Tea IPOH          NaN     4.0                  77
# 3                    18CTEA          2.0     3.9                 215
# 4                     Kitea          NaN     4.5                   6

# %%
dfIpoh2[dfIpoh2['name'].str.contains("Alley")]
# Out:
#                                              address  latitude   longitude  \
# 6  Blok D-G-15, Soho Ipoh, 2, Jalan Sultan Idris ...  4.592861  101.089847
#
#                   name  price_level  rating  user_ratings_total
# 6  The Alley Ipoh Soho          2.0     4.1                1064

# %%
dfIpoh2.describe()
# Out:
#         latitude   longitude  price_level     rating  user_ratings_total
# count  20.000000   20.000000          6.0  20.000000           20.000000
# mean    4.603357  101.097993          2.0   4.110000          107.300000
# std     0.021023    0.018784          0.0   0.543769          241.402939
# min     4.561071  101.075094          2.0   2.700000            2.000000
# 25%     4.592892  101.088222          2.0   3.900000            8.750000
# 50%     4.596447  101.090027          2.0   4.050000           17.500000
# 75%     4.615194  101.113105          2.0   4.500000           86.750000
# max     4.670742  101.150735          2.0   5.000000         1064.000000

# %%
dfIpoh2[dfIpoh2['rating'] > 4.5]
# Out:
#                                               address  latitude   longitude  \
# 15  11-13, Jalan Raja Dr. Nazrin Shah, Pusat Kesih...  4.561071  101.111966
# 16  61, Jalan Market, 30000 Ipoh, Negeri Perak, Ma...  4.595789  101.078687
# 18  1, Jalan Panglima, 30000 Ipoh, Negeri Perak, M...  4.596981  101.077463
#
#                     name  price_level  rating  user_ratings_total
# 15      Fengcha symphony          NaN     5.0                   2
# 16         Hearts Rabbit          NaN     4.8                  10
# 18  Teaaroi Vintage Ipoh          NaN     5.0                   4

# %%
map_Ipoh = folium.Map(location=[4.5975,101.0901], zoom_start=12)

for lat, lng, label in zip(dfIpoh2['latitude'], dfIpoh2['longitude'],dfIpoh2['name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        popup=label,
        color='black',
        fill=True,
        fill_color='black',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Ipoh)  
    
map_Ipoh
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # result

# %% [markdown]
# From the analysis, we found that there are a lot of bubble tea brand in Malaysia, some are not even known to the major public.
#
# From the analysis on the capital city, we found out that Tealive and The Alley are more celebrated by the people. With 4.3 rating being the top 25% for bubble tea rating, all 4 branches of the Alley in Kuala lumpur do achieve that level.
#
# However, in the case of Tealive, only certain branch achieve good rating, that shows the quality control is a problem for Tealive.
#
# When analysis Penang and Ipoh situation, The Alley was already exist in the market. However, it was not prominent. It is also note that, in Ipoh, independant bubble tea brand get higher rating than The Alley and other franchise household name.

# %% [markdown]
# # Discussion

# %% [markdown]
# There are too many household bubble tea brand in Malaysia, from tealive, The Alley, Xin Fu Tang to Black Whale and others. Among all these, The Alley seems to be better received by the public.
#
# For a interested franchisee, it is more recommanded to sign up for The Alley.
#
# However, there are a lot of limitation for the research.
#
# As first, the limitation of the data itself. While Google set a limitation on how many location one can retrieved, Foursquare are not useful in the case of Malaysia.
# Thus, a better dataset can give a better insight.
#
# Besides, the demograhic made up and taste, as well as culture of local population was not considerated. To further improve the result, more data can be included in the future.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Data science projects often have a lot of 'surprise', such as the lack of data or a in need of creative use of algorithm to come out with a best case that can suit the problem.
#
# In the case of Bubble tea, certainly, that too have a lot more room for improvement. However, data did give a better picture of the situation in Malaysia.
#
# While people often compare some brand face to face, people do have a preference when it comes to brand.
#
# One of the best conclusion for the study was in data science projects, the correct data can do wonders.
